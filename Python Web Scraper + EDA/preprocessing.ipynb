# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('jobs.csv')
df
# Out:
#                                                  role  \
# 0                           Data Analyst I - job post
# 1                             Data Analyst - job post
# 2                             Data Analyst - job post
# 3   Missouri Online Data Analyst I - Remote and Hy...
# 4   Temporary - Partime - Associate Data Scientist...
# 5               Data Analyst I (Part Time) - job post
# 6   Missouri Online Data Analyst I - Remote and Hy...
# 7                      Junior Data Analyst - job post
# 8                           Data Scientist - job post
# 9                  HealthCare Data Analyst - job post
# 10    TikTok Shop - Logistics Data Analyst - job post
# 11                            Data Analyst - job post
# 12                            Data Analyst - job post
# 13                          Data Scientist - job post
# 14          Missouri Online Data Analyst I - job post
#
#                             company_name            company_location  \
# ...

# %%
def calculate_salary(salary: str):
    """
    Compute yearly salary from hourly rate
    """
    salary = salary.split(' an hour')[0]
    salary = float(salary) * 40 * 52
    return f"{salary}"


def split_salary_range(salary: str):
    """
    From salary column form min and max salary columns
    Cast to float
    """
    if '-' in salary:
        min_salary, max_salary = salary.split(' - ')
    elif salary == '0':
        min_salary = max_salary = salary
    else:
        min_salary, max_salary = 0, salary
    return float(min_salary), float(max_salary)



df['role'] = df['role'].str.replace('- job post', '')

df['job_location'] = np.where(df['company_location'] == 'Remote', 'Remote', 'On-site')
df['job_location'] = np.where(df['company_location'].str.contains('•'), df['company_location'].str.split('•').str[1], df['job_location'])

df['company_location'] = np.where(df['company_location'] == 'Remote', '', df['company_location'])
df['company_location'] = df['company_location'].str.split('•').str[0]

df[['company_location', 'company_state']] = df['company_location'].str.split(', ', expand=True, )
df['company_state'].fillna('', inplace=True)
df['company_state'] = df['company_state'].str[:2]

df['company_rating'] = df['company_rating'].str.split(' out of ').str[0]
df['company_rating'] = df['company_rating'].fillna(0)
df['company_rating'] = pd.to_numeric(df['company_rating'])

df['salary'] = df['salary'].fillna('0')
df['salary'] = df['salary'].str.replace(' a year', '').str.replace('$', '').str.replace(',', '')
df['salary'] = df['salary'].apply(lambda x: calculate_salary(x) if 'hour' in x else x)
df[['min_salary', 'max_salary']] = df['salary'].apply(lambda x: pd.Series(split_salary_range(x)))
df.drop('salary', axis=1, inplace=True)

df['job_type'] = df['job_type'].str.lstrip(' -')
df['job_type'] = df['job_type'].fillna('')

df['description'] = df['description'].str.strip()

df.to_csv('preprocessed.csv', index=False)

df
# Out:
#                                                  role  \
# 0                                     Data Analyst I
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3   Missouri Online Data Analyst I - Remote and Hy...
# 4     Temporary - Partime - Associate Data Scientist
# 5                         Data Analyst I (Part Time)
# 6   Missouri Online Data Analyst I - Remote and Hy...
# 7                                Junior Data Analyst
# 8                                     Data Scientist
# 9                            HealthCare Data Analyst
# 10              TikTok Shop - Logistics Data Analyst
# 11                                      Data Analyst
# 12                                      Data Analyst
# 13                                    Data Scientist
# 14                    Missouri Online Data Analyst I
#
#                             company_name company_location  company_rating  \
# ...
