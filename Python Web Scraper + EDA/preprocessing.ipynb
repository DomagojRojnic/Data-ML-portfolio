# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('jobs.csv')
df
# Out:
#                                                    role  \
# 0           Data Analyst II - Trust & Safety - job post
# 1        Data Scientist – Learning Analytics - job post
# 2                               Data Analyst - job post
# 3     Missouri Online Data Analyst I - Remote and Hy...
# 4                               Data Analyst - job post
# ...                                                 ...
# 1058                            Data Analyst - job post
# 1059                     Senior Data Analyst - job post
# 1060                     Health Data Analyst - job post
# 1061                          Data Scientist - job post
# 1062                          Data Scientist - job post
#
#                                          company_name  \
# 0                                           Pinterest
# 1                                                 MIT
# 2                                        GitHub, Inc.
# 3                              University of Missouri
# 4                                     Everside Health
# ...                                               ...
# 1058                                         Truepill
# 1059                                       ServiceNow
# 1060  Blue Cross and Blue Shield of Nebraska (BCBSNE)
# 1061                              Key Cyber Solutions
# 1062                               CoventBridge Group
#
#                                 company_location      company_rating  \
# 0                       San Francisco, CA•Remote  3.8 out of 5 stars
# 1     600 Memorial Dr Ste 1, Cambridge, MA 02139  4.2 out of 5 stars
# 2                                         Remote  4.1 out of 5 stars
# 3                                Missouri•Remote  4.1 out of 5 stars
# 4                                         Remote    3 out of 5 stars
# ...                                          ...                 ...
# 1058                                      Remote  2.6 out of 5 stars
# 1059                  San Diego, CA 92121•Remote  3.8 out of 5 stars
# 1060                     Omaha, NE•Hybrid remote  3.9 out of 5 stars
# 1061                                Richmond, VA                 NaN
# 1062                               United States  2.6 out of 5 stars
#
#                           salary       job_type  \
# 0                            NaN            NaN
# 1     $110,000 - $125,000 a year   -  Full-time
# 2      $73,500 - $195,000 a year   -  Full-time
# 3       $60,000 - $69,000 a year   -  Full-time
# 4       $75,000 - $85,000 a year   -  Full-time
# ...                          ...            ...
# 1058   $90,000 - $130,000 a year   -  Full-time
# 1059   $84,870 - $140,130 a year   -  Full-time
# 1060                         NaN            NaN
# 1061                         NaN      Part-time
# 1062  $110,000 - $130,000 a year   -  Full-time
#
#                                             description
# 0     \n\nAbout Pinterest:\n Millions of people acro...
# 1     \n\n\nDATA SCIENTIST, LEARNING ANALYTICS, MIT ...
# 2     \n About GitHub: As the global home for all de...
# 3     \n\n\nHiring Department\n\n\n\n\n\neLearning\n...
# 4     \n\n  ABOUT THE JOB\n \n\n   The Data Analyst ...
# ...                                                 ...
# 1058  \nDescription \nAt Truepill, we power the futu...
# 1059  \nCompany Description\n At ServiceNow, our tec...
# 1060  \nBlue Cross and Blue Shield of Nebraska (BCBS...
# 1061  \nCompany Description\n Key Cyber Solutions (K...
# 1062  \n Overview: \n \n Data Scientist - REMOTE\n\n...
#
# [1063 rows x 7 columns]

# %%
def salary_to_min_max(salary: str):
    """
    Possible cases:
    $X a year/an hour
    $X - $Y a year/an hour
    $X - $Y a month
    Up to $X a year

    if given a single value, assume $0 - $X
    if given 'Up to $X', assume $0 - $X
    """
    salary = salary.lower()
    salary = salary.replace('$', '')
    salary = salary.replace(',', '')
    min_salary = max_salary = 0.0

    if 'up to' in salary:
        salary = salary.replace('up to', '')

    if 'year' in salary:
        min_salary, max_salary = get_min_max(salary, 'a year', 1)
    elif 'hour' in salary:
        min_salary, max_salary = get_min_max(salary, 'an hour', 40 * 52)
    elif 'month' in salary:
        min_salary, max_salary = get_min_max(salary, 'a month', 12)

    return min_salary, max_salary



def get_min_max(salary: str, replacement: str, multiplication: int):
    min_salary = max_salary = 0.0

    salary = salary.replace(replacement, '')
    salary = salary.strip()
    split = salary.split(' - ')

    # if range is given
    if len(split) == 2:
        min_salary, max_salary = split
        min_salary = float(min_salary) * multiplication
        max_salary = float(max_salary) * multiplication
    # if only a single value is given
    else:
        max_salary = float(split[0]) * multiplication

    return min_salary, max_salary



def split_location(location: str):
    city = state = None
    parts = location.split(', ')
    if len(parts) == 3:
        city = parts[1]
        state = parts[2][:2]
    elif len(parts) == 2:
        city = parts[0]
        state = parts[1][:2]
    else:
        city = parts[0]
    return city, state

# %%
df['role'] = df['role'].str.replace('- job post', '')

df['job_location'] = np.where(df['company_location'] == 'Remote', 'Remote', 'On-site')
df['job_location'] = np.where(df['company_location'].str.contains('•'), df['company_location'].str.split('•').str[1], df['job_location'])

df['company_location'] = np.where(df['company_location'] == 'Remote', '', df['company_location'])
df['company_location'] = df['company_location'].str.split('•').str[0]

df[['company_location', 'company_state']] = df['company_location'].apply(lambda x: pd.Series(split_location(x)))
df['company_state'].fillna('', inplace=True)

df['company_rating'] = df['company_rating'].str.split(' out of ').str[0]
df['company_rating'] = df['company_rating'].fillna(0)
df['company_rating'] = pd.to_numeric(df['company_rating'])

df['salary'] = df['salary'].fillna('0')
df[['min_salary', 'max_salary']] = df['salary'].apply(lambda x: pd.Series(salary_to_min_max(x)))
df.drop('salary', axis=1, inplace=True)

df['job_type'] = df['job_type'].str.lstrip(' -')
df['job_type'] = df['job_type'].fillna('')

df['description'] = df['description'].str.strip()

df
# Out:
#                                                    role  \
# 0                     Data Analyst II - Trust & Safety
# 1                  Data Scientist – Learning Analytics
# 2                                         Data Analyst
# 3     Missouri Online Data Analyst I - Remote and Hy...
# 4                                         Data Analyst
# ...                                                 ...
# 1058                                      Data Analyst
# 1059                               Senior Data Analyst
# 1060                               Health Data Analyst
# 1061                                    Data Scientist
# 1062                                    Data Scientist
#
#                                          company_name company_location  \
# 0                                           Pinterest    San Francisco
# 1                                                 MIT        Cambridge
# 2                                        GitHub, Inc.
# 3                              University of Missouri         Missouri
# 4                                     Everside Health
# ...                                               ...              ...
# 1058                                         Truepill
# 1059                                       ServiceNow        San Diego
# 1060  Blue Cross and Blue Shield of Nebraska (BCBSNE)            Omaha
# 1061                              Key Cyber Solutions         Richmond
# 1062                               CoventBridge Group    United States
#
#       company_rating   job_type  \
# 0                3.8
# 1                4.2  Full-time
# 2                4.1  Full-time
# 3                4.1  Full-time
# 4                3.0  Full-time
# ...              ...        ...
# 1058             2.6  Full-time
# 1059             3.8  Full-time
# 1060             3.9
# 1061             0.0  Part-time
# 1062             2.6  Full-time
#
#                                             description   job_location  \
# 0     About Pinterest:\n Millions of people across t...         Remote
# 1     DATA SCIENTIST, LEARNING ANALYTICS, MIT Open L...        On-site
# 2     About GitHub: As the global home for all devel...         Remote
# 3     Hiring Department\n\n\n\n\n\neLearning\n\n\n\n...         Remote
# 4     ABOUT THE JOB\n \n\n   The Data Analyst is res...         Remote
# ...                                                 ...            ...
# 1058  Description \nAt Truepill, we power the future...         Remote
# 1059  Company Description\n At ServiceNow, our techn...         Remote
# 1060  Blue Cross and Blue Shield of Nebraska (BCBSNE...  Hybrid remote
# 1061  Company Description\n Key Cyber Solutions (KCS...        On-site
# 1062  Overview: \n \n Data Scientist - REMOTE\n\n\n\...        On-site
#
#      company_state  min_salary  max_salary
# 0               CA         0.0         0.0
# 1               MA    110000.0    125000.0
# 2                      73500.0    195000.0
# 3                      60000.0     69000.0
# 4                      75000.0     85000.0
# ...            ...         ...         ...
# 1058                   90000.0    130000.0
# 1059            CA     84870.0    140130.0
# 1060            NE         0.0         0.0
# 1061            VA         0.0         0.0
# 1062                  110000.0    130000.0
#
# [1063 rows x 10 columns]

# %%
df.to_csv('preprocessed.csv', index=False)
